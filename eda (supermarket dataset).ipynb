# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("supermarket_sales - Sheet1.csv",parse_dates=['Date'])

# %% [markdown]
# **Attribute information**
#
# Invoice id: Computer generated sales slip invoice identification number
#
# Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# City: Location of supercenters
#
# Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# Gender: Gender type of customer
#
# Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# Unit price: Price of each product in $
#
# Quantity: Number of products purchased by customer
#
# Tax: 5% tax fee for customer buying
#
# Total: Total price including tax
#
# Date: Date of purchase (Record available from January 2019 to March 2019)
#
# Time: Purchase time (10am to 9pm)
#
# Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# COGS: Cost of goods sold
#
# Gross margin percentage: Gross margin percentage
#
# Gross income: Gross income
#
# Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# **1. Display top 5 rows of the dataset using head method**

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# **2.Display last 5 rows of the dataset.**

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %% [markdown]
# **3.Print random 5 rows from the dataset**

# %%
data.sample(5)
# Out:
#       Invoice ID Branch      City Customer type  Gender         Product line  \
# 755  652-43-6591      A    Yangon        Normal  Female  Fashion accessories
# 605  830-58-2383      B  Mandalay        Normal    Male   Home and lifestyle
# 212  142-63-6033      B  Mandalay        Normal    Male   Home and lifestyle
# 874  737-88-5876      A    Yangon        Member    Male   Home and lifestyle
# 309  848-42-2560      A    Yangon        Normal  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 755       97.29         8  38.916  817.236   3/9/2019  13:18  Credit card
# 605       31.75         4   6.350  133.350   2/8/2019  15:26         Cash
# 212       92.36         5  23.090  484.890  3/20/2019  19:17      Ewallet
# 874       23.29         4   4.658   97.818  3/19/2019  11:52  Credit card
# 309       81.91         2   8.191  172.011   3/5/2019  17:43         Cash
#
# ...

# %% [markdown]
# **4.Find the shape of the dataset (Number of columns & Number of columns)**

# %%
data.shape
# Out:
# (1000, 17)

# %% [markdown]
# **5.Check null values in the dataset**

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **6.Get information about the dataset (total number of rows ,total number of columns,datatypes of each column and memory requirement)**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# **7.Get overall statistics about the dataset.**

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
cat=[]
num=[]
for column in data.columns:
    if data[column].nunique() > 10:
         num.append(column)
    else:
       cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# **Univariate Analysis**

# %% [markdown]
# **1.Find aggregate sales among the branches.(categorical column)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert 'Branch' column to categorical type
data['Branch'] = data['Branch'].astype('category')

# Now, create the countplot
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
sns.countplot(x='Branch', data=data)

# Show the plot
plt.show()

# %%
data['Branch'].value_counts().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: ylabel='Branch'>

# %% [markdown]
# **2.Find the most popular payment method used by customers(categorical column)**

# %%
data['Payment'].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# **3.Find the distribution of customer ratings.(Numerical column)**

# %%
sns.distplot(data['Rating'])
# Out:
# <ipython-input-31-91d6e1ebbe22>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Rating'])
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# **4.Find the distribution of cost of goods sold(numerical column)**

# %%
sns.distplot(data['cogs'])
# Out:
# <ipython-input-33-fef88b5ea23f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['cogs'])
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(data['cogs'])
# Out:
# <Axes: >

# %% [markdown]
# **Bivaraiate Analysis/Multivariate Analysis**

# %% [markdown]
# **1.Does the cost of goods sold affect the ratings that the customers provide?(Numerical )**

# %%
import seaborn as sns

# Assuming your DataFrame is named 'data' with 'cogs' and 'Rating' columns
sns.scatterplot(x='cogs', y='Rating', data=data)
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# **2.Does Gross income affect the ratings that the customers provide?(numerical)**

# %%
sns.scatterplot(x='gross income', y='Rating', data=data)
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# **3.Find the most profitable branch as per gross income.(numerical-categorical)**

# %%
sns.barplot(x='Branch', y='gross income', data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x='Branch', y='gross income',hue=data['City'], data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# **4.Is there any relationship between gender and gross income?(numerical-categorical)**

# %%
sns.boxplot(x='Gender', y='gross income', data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x='Gender', y='gross income',hue=data['Customer type'], data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# **5.find the product line that generates the most income.(numerical-categorical)**

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(x='Product line', y='gross income',data=data)
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# **6.Highest unit price in the product line.(numerical-categorical)**

# %%
sns.barplot(x='Product line', y='Unit price',data=data)
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# **7.find the difference payment methods used by customers citywise(categorical-categorical)**

# %%
pd.crosstab(data['City'],data['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %% [markdown]
# **8.which product line is purchased in the highest quantity?**

# %%
(data.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# Out:
# <ipython-input-51-4ae4c7c8e139>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (data.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# <Axes: xlabel='Product line'>

# %% [markdown]
# **9.Display daily sales by day of the week**

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data['day_of_week']=data['Date'].dt.dayofweek.map(dw_mapping)

# %%
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating day_of_week
# 0                 4.761905       26.1415     9.1         sat

# %%
dw_mapping={
    0:'mon',
    1:'tue',
    2:'wed',
    3:'thu',
    4:'fri',
    5:'sat',
    6:'sun'
}

# %%
data['day_of_week'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **10.what will be the highest months for sales**

# %%
month_mapping={
    1:"jan",
    2:"feb",
    3:"mar"
}

# %%
data['month']=data['Date'].dt.month.map(month_mapping)

# %%
data['month'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
